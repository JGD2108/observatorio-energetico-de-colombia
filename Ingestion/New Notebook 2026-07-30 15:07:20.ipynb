# %%
import sys

project_root = (
    "/Workspace/Users/"
    "jgomezdelahoz2108@gmail.com/"
    "observatorio-energetico-de-colombia"
)

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from config.project_config import (
    CATALOG,
    LANDING_VOLUME,
    LOOKBACK_DAYS,
    BRONZE_TABLES,
    SILVER_TABLES,
    GOLD_TABLES,
)

# %%
print(CATALOG)
print(LANDING_VOLUME)
print(LOOKBACK_DAYS)
print(BRONZE_TABLES["generacion_real"])
