# %%
# %sql

CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.embalses(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key', 
    codigo_embalse STRING,
    nombre_embalse STRING,
    latitud STRING,
    longitud STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de embalses"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.niveles_embalses(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    codigo_variable STRING,
    fecha_inicio STRING,
    codigo_duracion STRING,
    unidad_medida STRING,
    codigo_planta STRING,
    version STRING,
    valor STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de NIVELES de embalses"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.plantas(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    fecha STRING,
    codigo_duracion STRING,
    codigo_planta STRING,
    nombre_planta STRING,
    codigo_sic_agente STRING,
    cap_efectiva_neta STRING,
    fpo STRING,
    codigo_sub_area_operativa STRING, 
    codigo_area_operativa STRING, 
    tipo_despacho_recurso STRING,
    tipo_clasificacion STRING,
    tipo_generacion STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de plantas de generación que se alimentan de los embalses"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.plantas_reservorios(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    region STRING,
    nombre_planta STRING,
    nombre_reservorio STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
)USING DELTA 
TBLPROPERTIES(
    "COMMENT" = "Tabla para conectar embalses y reservorios"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.generacion_real(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    codigo_variable STRING,
    fecha_hora STRING,
    codigo_duracion STRING,
    unidad_medida STRING,
    codigo_sic_agente STRING,
    codigo_planta STRING,
    version STRING,
    valor STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de generacion real"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.demanda_real(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    codigo_variable STRING,
    fecha_hora STRING,
    codigo_sic_agente STRING,
    tipo_mercado STRING, 
    version STRING,
    valor STRING,
    unidad_medida STRING,
    codigo_duracion STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de demanda real"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.precio_bolsa(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    codigo_variable STRING,
    fecha_hora STRING,
    codigo_duracion STRING,
    unidad_medida STRING,
    version STRING,
    valor STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de precios de bolsa"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.disponibilidad_plantas(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    codigo_variable STRING,
    fecha_hora STRING,
    codigo_duracion STRING,
    unidad_medida STRING,
    codigo_planta STRING,
    version STRING,
    valor STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
) USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de disponibilidad de plantas"
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS observatorio_dev.bronze.agentes(
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'Surrogate key',
    fecha STRING,
    codigo_duracion STRING,
    codigo_sic_agente STRING,
    nombre_agente STRING,
    actividad_agente STRING,
    source_file_name STRING,
    source_file_path STRING,
    ingestion_timestamp TIMESTAMP,
    load_date DATE
)USING DELTA
TBLPROPERTIES(
    "COMMENT" = "Tabla de agentes"
)
